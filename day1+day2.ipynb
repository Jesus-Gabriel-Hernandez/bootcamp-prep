# %%
# Día 2

# Lista frutas
fruits_list = []

print("Lista original ",fruits_list)
# Agrego frutas como Sandía, Manzana y Banana

fruits_list.append("Sandía")
fruits_list.append("Manzana")
fruits_list.append("Banana")
fruits_list.append("Arándanos")
print("Lista tras el append", fruits_list)

fruits_list.remove("Manzana")

print("Lista tras el remove", fruits_list)

fruits_list.sort()

print("Lista ordenada", fruits_list)

print("probando el slicing ",fruits_list[1:3])

print("\n")
#Ejercicios diccionarios

notas = {"Ana": 8, "Luis": 8, "Marta": 9}

notas["Gregorio"] =7

print("La nota de Ana es ",notas["Ana"])

for llave,valor in notas.items():
    print("La clave del diccionario es: ", llave, " y su valor es: ",valor)


# Preguntar edad

user_age= input("Escribe un número y te doy un mensaje: ")

if(not user_age.isnumeric()):
    print("ingresa un número")
    user_age= input("Escribe un número y te doy un mensaje: ")
else:
    int_age = int(user_age) 
    if(int_age < 18):
        print("Menor de edad", int_age)
    elif(int_age >= 18 and int_age <= 65):
        print("Adulto",int_age)
    elif(int_age > 65):
        print("Senior",int_age)
    else:
        print("Edad ilógica o fallo del sistema")

# Reto nota alumnos

vector_notas = [7, 8, 9, 5, 10]

# Mayor nota

mayor_nota = max(vector_notas)
print(mayor_nota)

# Mínima nota
menor_nota = min(vector_notas)
print(menor_nota)

# Promedio

promedio_notas = (sum(vector_notas))/len(vector_notas)
print(promedio_notas)


# Reto 2, bucle + condicionales

frutitas =["Manzana","Pera","Naranja"]

print(frutitas)
user_option = input("¿Qué quieres hacer? Opciones: Añadir, eliminar o mostrar")

real_option = user_option.lower()
opciones_validas =["añadir","eliminar","mostrar"]
while real_option in opciones_validas:
    if(real_option=="añadir"):
        fruta= input("Di el elemento a añadir: ")
        frutitas.append(fruta)
    elif(real_option=="eliminar"):
        fruta= input("Di el elemento a destruir: ")
        if(fruta in frutitas):
            frutitas.remove(fruta)
        else:
            print("La fruta no existe")
    elif(real_option=="mostrar"):
        print(frutitas)
user_option = input("¿Qué quieres hacer? Opciones: Añadir, eliminar,mostrar u otra cosa para salir:")
print("Programa terminado")
# Out:
# Lista original  []
# Lista tras el append ['Sandía', 'Manzana', 'Banana', 'Arándanos']
# Lista tras el remove ['Sandía', 'Banana', 'Arándanos']
# Lista ordenada ['Arándanos', 'Banana', 'Sandía']
# probando el slicing  ['Banana', 'Sandía']
#
#
# La nota de Ana es  8
# La clave del diccionario es:  Ana  y su valor es:  8
# La clave del diccionario es:  Luis  y su valor es:  8
# La clave del diccionario es:  Marta  y su valor es:  9
# La clave del diccionario es:  Gregorio  y su valor es:  7
# Escribe un número y te doy un mensaje:  43
# Adulto 43
# 10
# 5
# 7.8
# ['Manzana', 'Pera', 'Naranja']
# ¿Qué quieres hacer? Opciones: Añadir, eliminar o mostrar Añadir

# %%
#Día 1 
# Mostrar mensaje

print("Hola Data Scinece")


# Calcular media números
lista_num = [1,2,3,4,5]

add_elements = 0

if(len(lista_num) !=5):
    print("Lista mínimo con 5 nombres")
else:
    for elements in lista_num:
        add_elements += elements
        result = add_elements / len(lista_num)
print(result)

print("\n")
# Bucle para imprimir elementos
for x in range(1,11):
    print("X es igual a ", x)


# Calculadora Celcius a Fahrenheit

user_temp = input("Escribe una temperatura en Cº para pasarla a Fº")

def Celcius_to_Fahrenheit(temperature):

    float_temp = float(user_temp)

    fahren_result = (float_temp * 9/5)+32
    return  print(fahren_result,"ºF")
    
Celcius_to_Fahrenheit(user_temp)
# Out:
# Hola Data Scinece
# 3.0
# Escribe una temperatura en Cº para pasarla a Fº 23
# 73.4 ºF
